# %% [markdown]
# ## DICTIONARY TO LIST THE PARAMETERS TO AUTOMATE ETL

# %%
my_gold_array = [
    {
        "source_catalog": "olympicspariscatalog",
        "sink_container": "gold",
        "folder": "coaches"
    },
    {
        "source_catalog": "olympicspariscatalog",
        "sink_container": "gold",
        "folder": "athletes"
    },
    {
        "source_catalog": "olympicspariscatalog",
        "sink_container": "gold",
        "folder": "events"
    },
    {
        "source_catalog": "olympicspariscatalog",
        "sink_container": "gold",
        "folder": "nocs"
    }
]

# %%
dbutils.jobs.taskValues.set(key = "my_gold_output", value = my_gold_array)
